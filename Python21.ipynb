# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('mtcars.csv')

# %%
df
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df.mean()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7684\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7684\3676274908.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean(axis=1)
# 0     29.907273
# 1     29.981364
# 2     23.598182
# 3     38.739545
# 4     53.664545
# 5     35.049091
# 6     59.720000
# 7     24.634545
# 8     27.233636
# 9     31.860000
# 10    31.787273
# 11    46.430909
# 12    46.500000
# 13    46.350000
# 14    66.232727
# 15    66.058545
# 16    65.972273
# 17    19.440909
# 18    17.742273
# 19    18.814091
# 20    24.888636
# 21    47.240909
# 22    46.007727
# 23    58.752727
# 24    57.379545
# 25    18.928636
# 26    24.779091
# 27    24.880273
# 28    60.971818
# 29    34.508182
# 30    63.155455
# 31    26.262727
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7684\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# mpg      19.200
# cyl       6.000
# disp    196.300
# hp      123.000
# drat      3.695
# wt        3.325
# qsec     17.710
# vs        0.000
# am        0.000
# gear      4.000
# carb      2.000
# dtype: float64

# %%
disp=df.median(axis=1)
disp
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7684\2770987561.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   disp=df.median(axis=1)
# 0     4.000
# 1     4.000
# 2     4.000
# 3     3.215
# 4     3.440
# 5     3.460
# 6     4.000
# 7     4.000
# 8     4.000
# 9     4.000
# 10    4.000
# 11    4.070
# 12    3.730
# 13    3.780
# 14    5.250
# 15    5.424
# 16    5.345
# 17    4.000
# 18    4.000
# 19    4.000
# 20    3.700
# 21    3.520
# 22    3.435
# 23    4.000
# 24    3.845
# 25    4.000
# 26    4.430
# 27    4.000
# 28    5.000
# 29    6.000
# 30    8.000
# 31    4.000
# dtype: float64

# %%
plt.plot(df['disp'])
m=df.mean
sd=df.std
plt.vlines(disp.mean(), ymin=0, ymax=0.4)

# %%
norm_data = pd.DataFrame(np.random.normal(size=100))
norm_data.plot(kind="density",figsize=(8,6))
plt.vlines(norm_data.mean(),ymin=0,ymax=0.5,linewidth=5.0)
plt.vlines(norm_data.median(),ymin=0,ymax=0.5,linewidth=2.0,color="yellow")

# %%
df['disp']
# Out:
# 0     160.0
# 1     160.0
# 2     108.0
# 3     258.0
# 4     360.0
# 5     225.0
# 6     360.0
# 7     146.7
# 8     140.8
# 9     167.6
# 10    167.6
# 11    275.8
# 12    275.8
# 13    275.8
# 14    472.0
# 15    460.0
# 16    440.0
# 17     78.7
# 18     75.7
# 19     71.1
# 20    120.1
# 21    318.0
# 22    304.0
# 23    350.0
# 24    400.0
# 25     79.0
# 26    120.3
# 27     95.1
# 28    351.0
# 29    145.0
# 30    301.0
# 31    121.0
# Name: disp, dtype: float64

# %%
df
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df.mean()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7684\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64

# %%
plt.plot(df)
plt.vlines(df.mean(),ymin=0,ymax=0.4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7684\1913241401.py in <module>
# ----> 1 plt.plot(df)
#       2 plt.vlines(df.mean(),ymin=0,ymax=0.4)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
# ...

# %%
df1 = pd.DataFrame(np.random.exponential(size=100))

df1.plot(kind="density",figsize=(9,8),xlim=(-1,5))

plt.vlines(df1.mean(),ymin=0,ymax=0.9,linewidth=2,color="green")
plt.vlines(df1.median(),ymin=0,ymax=0.9,linewidth=2,color="Yellow")

# %%
df.mode()
# Out:
#              Unnamed: 0   mpg  cyl   disp     hp  drat    wt   qsec   vs   am  \
# 0           AMC Javelin  10.4  8.0  275.8  110.0  3.07  3.44  17.02  0.0  0.0
# 1    Cadillac Fleetwood  15.2  NaN    NaN  175.0  3.92   NaN  18.90  NaN  NaN
# 2            Camaro Z28  19.2  NaN    NaN  180.0   NaN   NaN    NaN  NaN  NaN
# 3     Chrysler Imperial  21.0  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 4            Datsun 710  21.4  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 5      Dodge Challenger  22.8  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 6            Duster 360  30.4  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 7          Ferrari Dino   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 8              Fiat 128   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 9             Fiat X1-9   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 10       Ford Pantera L   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# ...

# %% [markdown]
# ## Measures of Spread

# %%
max(df["disp"]) - min(df["disp"])
# Out:
# 400.9

# %%
Quartiles = [df["disp"].quantile(0),df["disp"].quantile(0.25),df["disp"].quantile(0.50),df["disp"].quantile(0.75),
             df["disp"].quantile(1)]
Quartiles
# Out:
# [71.1, 120.825, 196.3, 326.0, 472.0]

# %%
df["disp"].describe()
# Out:
# count     32.000000
# mean     230.721875
# std      123.938694
# min       71.100000
# 25%      120.825000
# 50%      196.300000
# 75%      326.000000
# max      472.000000
# Name: disp, dtype: float64

# %%
df["disp"].quantile(0.75) - df["disp"].quantile(0.25)
# Out:
# 205.175

# %%
df["disp"].var()
# Out:
# 15360.799828629031

# %%
df["disp"].std()
# Out:
# 123.93869383138194

# %% [markdown]
# ## Skewness and Kurtosis

# %%
df["disp"].skew()
# Out:
# 0.42023312147004516

# %%
df["disp"].kurt()
# Out:
# -1.0675234001434708

# %%
norm_data = np.random.normal(size=100000)
skewed_data = np.concatenate((np.random.normal(size=35000)+2, 
                             np.random.exponential(size=65000)), 
                             axis=0)
uniform_data = np.random.uniform(0,2, size=100000)
peaked_data = np.concatenate((np.random.exponential(size=50000),
                             np.random.exponential(size=50000)*(-1)),
                             axis=0)

data_df = pd.DataFrame({"norm":norm_data,
                       "skewed":skewed_data,
                       "uniform":uniform_data,
                       "peaked":peaked_data})

# %%
data_df.plot(kind="density",
            figsize=(10,10),
            xlim=(-5,5));

# %%
data_df.skew()
# Out:
# norm      -0.004800
# skewed     0.990240
# uniform    0.008365
# peaked    -0.040837
# dtype: float64

# %%
data_df.kurt()
# Out:
# norm       0.008422
# skewed     1.236814
# uniform   -1.198518
# peaked     2.992161
# dtype: float64
